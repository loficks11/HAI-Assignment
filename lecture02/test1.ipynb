# %%
import numpy as np
import pandas as pd

data = {
    '날짜': ['3/20', '3/21', '3/22', '3/23', '3/24'],
    '매출 편차': np.random.randn(5),
    '손님 평균 연령': np.random.randint(10, 60, 5)
}

df = pd.DataFrame(data)
df
# Out:
#      날짜     매출 편차  손님 평균 연령
# 0  3/20  1.936268        46
# 1  3/21 -1.931592        22
# 2  3/22 -0.393703        10
# 3  3/23  0.585242        47
# 4  3/24 -1.430491        21

# %%
df['매출 편차']
# Out:
# 0    1.936268
# 1   -1.931592
# 2   -0.393703
# 3    0.585242
# 4   -1.430491
# Name: 매출 편차, dtype: float64

# %%
df[df['손님 평균 연령'] >= 20]
# Out:
#      날짜     매출 편차  손님 평균 연령
# 0  3/20  1.936268        46
# 1  3/21 -1.931592        22
# 3  3/23  0.585242        47
# 4  3/24 -1.430491        21

# %%
df.loc[2, '매출 편차'] = np.nan
df.iloc[4, 2] = np.nan
df
# Out:
#      날짜     매출 편차  손님 평균 연령
# 0  3/20  1.936268      46.0
# 1  3/21 -1.931592      22.0
# 2  3/22       NaN      10.0
# 3  3/23  0.585242      47.0
# 4  3/24 -1.430491       NaN

# %%
df.isnull()
# Out:
#       날짜  매출 편차  손님 평균 연령
# 0  False  False     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False  False      True

# %%
df.fillna({'매출 편차': 0}, inplace = True)
df
# Out:
#      날짜     매출 편차  손님 평균 연령
# 0  3/20  1.936268      46.0
# 1  3/21 -1.931592      22.0
# 2  3/22  0.000000      10.0
# 3  3/23  0.585242      47.0
# 4  3/24 -1.430491       NaN

# %%
df.fillna({'손님 평균 연령': df['손님 평균 연령'].mean()}, inplace=True)
df
# Out:
#      날짜     매출 편차  손님 평균 연령
# 0  3/20  1.936268     46.00
# 1  3/21 -1.931592     22.00
# 2  3/22  0.000000     10.00
# 3  3/23  0.585242     47.00
# 4  3/24 -1.430491     31.25
