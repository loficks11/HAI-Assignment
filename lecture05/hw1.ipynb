# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
from PIL import Image
import torch
from torchvision import transforms
import matplotlib.pyplot as plt

image1 = Image.open('image1.jpg')
image2 = Image.open('image2.jpg')

# image1 = image1.resize((640, 360))
# image2 = image2.resize((640, 360))

transform = transforms.ToTensor()
image_tensor1 = transform(image1)
image_tensor2 = transform(image2)

# %%
plt.imshow(image_tensor1.permute(1, 2, 0))
plt.show()
plt.imshow(image_tensor2.permute(1, 2, 0))
plt.show()

# %%
print(image_tensor1.shape)
print(image_tensor2.dtype)
print(image_tensor2.shape)
print(image_tensor2.dtype)

res1 = torch.add(image_tensor1, image_tensor2)

plt.imshow(res1.permute(1, 2, 0))
plt.show()

res2 = image_tensor1 * image_tensor2

print(f"the matrix multiplication of image1 and image2 is \n{res2}")
# Out:
# torch.Size([3, 2160, 3840])
# torch.float32
# torch.Size([3, 2160, 3840])
# torch.float32
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.0].
# the matrix multiplication of image1 and image2 is
# tensor([[[0.0310, 0.0238, 0.0262,  ..., 0.0639, 0.0592, 0.0663],
#          [0.0143, 0.0262, 0.0310,  ..., 0.0616, 0.0639, 0.0734],
#          [0.0191, 0.0334, 0.0286,  ..., 0.0616, 0.0616, 0.0663],
#          ...,
#          [0.0328, 0.0311, 0.0413,  ..., 0.1562, 0.1641, 0.1914],
#          [0.0443, 0.0433, 0.0457,  ..., 0.1914, 0.1953, 0.2148],
#          [0.0642, 0.0610, 0.0461,  ..., 0.2344, 0.2266, 0.2148]],
#
#         [[0.0668, 0.0585, 0.0612,  ..., 0.0931, 0.0878, 0.0958],
#          [0.0473, 0.0612, 0.0668,  ..., 0.0905, 0.0931, 0.1038],
#          [0.0529, 0.0696, 0.0640,  ..., 0.0905, 0.0905, 0.0958],
#          ...,
#          [0.0973, 0.0915, 0.1013,  ..., 0.1276, 0.1349, 0.1604],
#          [0.1077, 0.1064, 0.1103,  ..., 0.1604, 0.1640, 0.1822],
#          [0.1286, 0.1260, 0.1039,  ..., 0.1932, 0.1859, 0.1749]],
#
#         [[0.1475, 0.1375, 0.1408,  ..., 0.1765, 0.1702, 0.1797],
#          [0.1240, 0.1408, 0.1475,  ..., 0.1734, 0.1765, 0.1892],
#          [0.1307, 0.1509, 0.1442,  ..., 0.1734, 0.1734, 0.1797],
#          ...,
#          [0.1446, 0.1403, 0.1552,  ..., 0.1350, 0.1414, 0.1639],
#          [0.1595, 0.1576, 0.1621,  ..., 0.1607, 0.1639, 0.1800],
#          [0.1980, 0.1901, 0.1628,  ..., 0.1928, 0.1864, 0.1768]]])
